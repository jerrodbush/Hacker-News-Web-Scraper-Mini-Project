# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

res = requests.get('https://news.ycombinator.com/news')
res2 = requests.get('https://news.ycombinator.com/news?p=2')
soup = BeautifulSoup(res.text, 'html.parser')
soup2 = BeautifulSoup(res2.text, 'html.parser')

links = soup.select('.titleline > a')
subtext = soup.select('.subtext')
links2 = soup2.select('.titleline > a')
subtext2 = soup2.select('.subtext')

mega_links = links + links2
mega_subtext = subtext + subtext2

def sort_stories_by_votes(hnlist):
    return sorted(hnlist, key=lambda k: k['votes'], reverse=True)

def create_custom_hn(links, subtext):
    hn = []
    for idx, item in enumerate(links):
        title = item.getText()
        href = item.get('href', None)
        vote = subtext[idx].select('.score')
        if len(vote):
            points = int(vote[0].getText().replace(' points', ''))
            if points > 50:
                hn.append({'title': title, 'link': href, 'votes': points})
    return sort_stories_by_votes(hn)

data = create_custom_hn(mega_links, mega_subtext)
df = pd.DataFrame(data, columns=['title', 'link', 'votes'])

print(df)
# Out:
#                                                 title  \
# 0   RedPajama: Reproduction of LLaMA with friendly...
# 1                                      Load Balancing
# 2                                              Astral
# 3   Software firms across US facing tax bills that...
# 4   Marginalia: DIY search engine that focuses on ...
# 5                                               Clock
# 6         An example of LLM prompting for programming
# 7   Microsoft plugging more ads into Windows 11 St...
# 8   Firefox may soon reject Cookie prompts automat...
# 9            A WWII spy who hid codes in her knitting
# 10  Giant SpaceX Spiral Appears Amid the Aurora Li...
# 11     PSA: Upgrade your LUKS key derivation function
# 12    Netflix will end its DVD service after 25 years
# 13  French publisher arrested in London for refusa...
# 14   Meta is about to start its next round of layoffs
# 15   Reddit will begin charging for access to its API
# 16     Brain images just got 64 million times sharper
# 17                   Apple’s agreement with Cupertino
# 18              Lightweight SQLite Editor for Windows
# 19  NSO developed 3 new ways to hack iPhones, Citi...
# 20                          Broadband Consumer Labels
# 21                                 My Emacs eye candy
# 22  Why do ships use “port” and “starboard” instea...
# 23                                        Tag Systems
# 24                        Node.js 20 is now available
# 25         LLaVA: Large Language and Vision Assistant
# 26                             NIST Privacy Framework
# 27  MMC4: An open, billion-scale corpus of images ...
# 28                         Borland C++ Builder (2015)
# 29       Mouse Cursor History (and why I made my own)
# 30  Google search partial outage while rolling out...
# 31  Synthetic Data from Diffusion Models Improves ...
# 32  Southwest Airlines pauses departures after rep...
# 33                   Horrible Code, Clean Performance
#
#                                                  link  votes
# 0             https://www.together.xyz/blog/redpajama    827
# 1                  https://samwho.dev/load-balancing/    763
# 2                                  https://astral.sh/    729
# 3   https://www.cnbc.com/2023/04/18/software-firms...    566
# 4                       https://search.marginalia.nu/    478
# 5                        https://oimo.io/works/clock/    434
# 6   https://martinfowler.com/articles/2023-chatgpt...    431
# 7   https://www.theregister.com/2023/04/17/microso...    324
# 8   https://www.ghacks.net/2023/04/17/firefox-may-...    318
# 9            https://www.amightygirl.com/blog?p=25020    281
# 10  https://petapixel.com/2023/04/17/giant-spiral-...    260
# 11            https://mjg59.dreamwidth.org/66429.html    251
# 12  https://www.nytimes.com/2023/04/18/business/me...    231
# 13  https://www.theguardian.com/uk-news/2023/apr/1...    227
# 14  https://www.vox.com/technology/2023/4/18/23688...    213
# 15  https://www.nytimes.com/2023/04/18/technology/...    211
# 16  https://medicalxpress.com/news/2023-04-brain-i...    192
# 17  https://news.bloombergtax.com/tax-insights-and...    157
# 18       https://github.com/little-brother/sqlite-gui    153
# 19  https://www.washingtonpost.com/technology/2023...    106
# 20                https://www.fcc.gov/broadbandlabels    101
# 21           https://xenodium.com/my-emacs-eye-candy/     91
# 22  https://oceanservice.noaa.gov/facts/port-starb...     91
# 23  https://buttondown.email/hillelwayne/archive/t...     91
# 24  https://nodejs.org/en/blog/announcements/v20-r...     89
# 25                        https://llava-vl.github.io/     84
# 26             https://www.nist.gov/privacy-framework     81
# 27                    https://github.com/allenai/mmc4     78
# 28  http://runtimeterror.com/blog/borland-c-builde...     76
# 29        https://www.youtube.com/watch?v=YThelfB2fvg     76
# 30                                   item?id=35622847     73
# 31                   https://arxiv.org/abs/2304.08466     70
# 32  https://www.cnbc.com/2023/04/18/southwest-airl...     69
# 33  https://johnnysswlab.com/horrible-code-clean-p...     66
